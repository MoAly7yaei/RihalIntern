# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from random import randint

# %%
#Create dummy data

data = {
    'X' : [((i*3)-randint(a = -1, b = 1)) for i in range(100)],
    'y' : [j for j in range(100)]
}
df = pd.DataFrame(data)

# %%
import GradientDecentSecondTry as gd

# %%
X = df['X']
y = df['y']

# %%
plt.figure()
plt.scatter(X,y)
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
model = gd.Regression()  # Create an instance without setting epochs

# %%
gd.Regression.try_the_algorithm()
# Out:
# 1.9930000000000159 0.08700000000000013

# %%
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 model.fit(X_train, y_train)
#
# File c:\Users\MoAly\OneDrive - Rihal\Rihal\Projects\RihalIntern\Stage Two\GradientDecentSecondTry.py:49, in Regression.fit(self, x, y)
#      48 def fit(self, x, y):
# ---> 49     return self.algorithm(x, y)
#
# File c:\Users\MoAly\OneDrive - Rihal\Rihal\Projects\RihalIntern\Stage Two\GradientDecentSecondTry.py:25, in Regression.algorithm(self, x, y)
#      22     self.val1 += self.learning_rate
#      23     self.val2 = self.val2 - self.learning_rate if self.val2 >= 0 else self.val2 + self.learning_rate
# ---> 25 mse, m = self.deploy_values(self.val1, self.val2, x, y)
#      26 mse_list.append(mse)
#      27 m_list.append(m)
#
# File c:\Users\MoAly\OneDrive - Rihal\Rihal\Projects\RihalIntern\Stage Two\GradientDecentSecondTry.py:40, in Regression.deploy_values(m, b, x, y)
#      38 @staticmethod
#      39 def deploy_values(m, b, x, y):
# ---> 40     y_pred = (m * x) + b
#      41     mse = ((y - y_pred) ** 2).mean()
#      42     return mse, m
#
# File c:\Users\MoAly\OneDrive - Rihal\Rihal\Projects\RihalIntern\rihal\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\MoAly\OneDrive - Rihal\Rihal\Projects\RihalIntern\rihal\Lib\site-packages\pandas\core\arraylike.py:206, in OpsMixin.__rmul__(self, other)
#     204 @unpack_zerodim_and_defer("__rmul__")
#     205 def __rmul__(self, other):
# --> 206     return self._arith_method(other, roperator.rmul)
#
# File c:\Users\MoAly\OneDrive - Rihal\Rihal\Projects\RihalIntern\rihal\Lib\site-packages\pandas\core\series.py:6115, in Series._arith_method(self, other, op)
#    6113 def _arith_method(self, other, op):
#    6114     self, other = self._align_for_op(other)
# -> 6115     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File c:\Users\MoAly\OneDrive - Rihal\Rihal\Projects\RihalIntern\rihal\Lib\site-packages\pandas\core\base.py:1382, in IndexOpsMixin._arith_method(self, other, op)
#    1379     rvalues = np.arange(rvalues.start, rvalues.stop, rvalues.step)
#    1381 with np.errstate(all="ignore"):
# -> 1382     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1384 return self._construct_result(result, name=res_name)
#
# File c:\Users\MoAly\OneDrive - Rihal\Rihal\Projects\RihalIntern\rihal\Lib\site-packages\pandas\core\ops\array_ops.py:283, in arithmetic_op(left, right, op)
#     279     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#     281     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     282     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 283     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     285 return res_values
#
# File c:\Users\MoAly\OneDrive - Rihal\Rihal\Projects\RihalIntern\rihal\Lib\site-packages\pandas\core\ops\array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     215     func = partial(expressions.evaluate, op)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#     220     if not is_cmp and (
#     221         left.dtype == object or getattr(right, "dtype", None) == object
#     222     ):
#    (...)
#     225         # Don't do this for comparisons, as that will handle complex numbers
#     226         #  incorrectly, see GH#32047
#
# KeyboardInterrupt:
