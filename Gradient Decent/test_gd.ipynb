# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from random import randint

# %%
#Create dummy data

data = {
    'X' : [((i*3)-randint(a = -1, b = 1)) for i in range(10000)],
    'y' : [j for j in range(10000)]
}
df = pd.DataFrame(data)

# %%
import GradientDecentSecondTry as gd

# %%
X = df['X']
y = df['y']

# %%
plt.figure()
plt.scatter(X,y)
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
model = gd.Regression()  # Create an instance without setting epochs

# %%
gd.Regression.try_the_algorithm() #(y = 2x) ----> The Expected reasult
# Out:
# 0.03299999999999079 0.0990000000000002

# %%
model = model.fit(X_train, y_train)

# %%
model
# Out:
# (20757742.379622657,
#  0.07099999999999373,
#  0.060999999999990395,
#  [13390096460.103579,
#   12991150984.527288,
#   12598238832.169174,
#   12211360003.029247,
#   11830514497.107502,
#   11455702314.403934,
#   11086923454.91855,
#   10724177918.651346,
#   10367465705.602325,
#   10016786815.771486,
#   9672141249.158825,
#   9333529005.764347,
#   9000950085.58805,
#   8674404488.629936,
#   8353892214.890002,
#   8039413264.368248,
#   7730967637.064677,
#   7428555332.979285,
#   7132176352.112077,
#   6841830694.463049,
#   6557518360.032205,
#   6279239348.819537,
#   6006993660.825054,
#   5740781296.048752,
#   5480602254.490629,
#   5226456536.150688,
#   4978344141.028928,
#   4736265069.12535,
#   4500219320.439953,
#   4270206894.972737,
#   4046227792.723703,
#   3828282013.69285,
#   3616369557.880178,
#   3410490425.285688,
#   3210644615.9093785,
#   3016832129.751251,
#   2829052966.811305,
#   2647307127.08954,
#   2471594610.585956,
#   2301915417.3005543,
# ...

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')  # Create a 3D subplot

ax.scatter(model[5], model[4], model[3], c='red', label='MSE')

ax.set_xlabel('Slope (m)')
ax.set_ylabel('Intercept (b)')
ax.set_zlabel('MSE')

plt.legend()
plt.show()

# %%
"""
supposed to be the reasult based on the data givin is
m = 3, b = 0
"""

m = model[1]
b = model[2]
m,b
# Out:
# (0.07099999999999373, 0.060999999999990395)
