# %%
import torch
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# https://www.kaggle.com/datasets/mohamedkhaledelsafty/best-arabic-poem-comprehensive-dataset

# %%
WORK_DIR = os.getcwd()

# %%
WORK_DIR
# Out:
# '/home/powerfull/Development/RihalIntern/Poem Classifier'

# %%
DATAPATH = WORK_DIR + '/data'

# %%
DATAPATH
# Out:
# '/home/powerfull/Development/RihalIntern/Poem Classifier/data'

# %%
data = pd.read_csv(DATAPATH + '/data.csv')

# %%
data.head()
# Out:
#          العصر             الشاعر          الديوان القافية   البحر  \
# 0  قبل الإسلام  عمرو بنِ قُمَيئَة  الديوان الرئيسي       د  الطويل
# 1  قبل الإسلام  عمرو بنِ قُمَيئَة  الديوان الرئيسي       د  الطويل
# 2  قبل الإسلام  عمرو بنِ قُمَيئَة  الديوان الرئيسي       د  الطويل
# 3  قبل الإسلام  عمرو بنِ قُمَيئَة  الديوان الرئيسي       د  الطويل
# 4  قبل الإسلام  عمرو بنِ قُمَيئَة  الديوان الرئيسي       د  الطويل
#
#                             الشطر الايسر  \
# 0   وَأَن تَجمَعا شَملي وَتَنتَظِرا غَدا
# 1  وَلا سُرعَتي يَوماً بِسابِقَةِ الرَدى
# 2  وَتَستَوجِبا مَنّاً عَلَيَّ وَتُحمَدا
# 3    تُؤامِرُني سِرّاً لِأَصرِمَ مَرثَدا
# 4   وَأَفرَعَ في لَومي مِراراً وَأَصعَدا
#
#                              الشطر الايمن  \
# 0   خَليلَيَّ لا تَستَعجِلا أَن تَزَوَّدا
# 1     فَما لَبَثٌ يَوماً بِسابِقٍ مَغنَمٍ
# 2  وَإِن تُنظِراني اليَومَ أَقضِ لُبانَةً
# 3      لَعَمرُكَ ما نَفسٌ بِجِدٍ رَشيدَةٍ
# 4    وَإِن ظَهَرَت مِنهُ قَوارِصُ جَمَّةٌ
#
#                                                البيت
# 0  خَليلَيَّ لا تَستَعجِلا أَن تَزَوَّدا    وَأَن...
# 1  فَما لَبَثٌ يَوماً بِسابِقٍ مَغنَمٍ    وَلا سُ...
# 2  وَإِن تُنظِراني اليَومَ أَقضِ لُبانَةً    وَتَ...
# 3  لَعَمرُكَ ما نَفسٌ بِجِدٍ رَشيدَةٍ    تُؤامِرُ...
# 4  وَإِن ظَهَرَت مِنهُ قَوارِصُ جَمَّةٌ    وَأَفر...

# %%
set(data['القافية'])
# Out:
# {'-',
#  nan,
#  'ء',
#  'ؤ',
#  'ا',
#  'ب',
#  'ة',
#  'ت',
#  'ث',
#  'ج',
#  'ح',
#  'خ',
#  'د',
#  'ذ',
#  'ر',
#  'ز',
#  'س',
#  'ش',
#  'ص',
#  'ض',
#  'ط',
#  'طن',
#  'ظ',
#  'ع',
#  'غ',
#  'ف',
#  'ق',
#  'ك',
#  'ل',
#  'لا',
#  'م',
#  'ن',
#  'ه',
#  'هـ',
#  'هن',
#  'و',
#  'ى',
#  'ي'}

# %%
set(data['البحر'])
# Out:
# {nan,
#  'البسيط',
#  'الخفيف',
#  'الدوبيت',
#  'الرجز',
#  'الرمل',
#  'السريع',
#  'السلسلة',
#  'الطويل',
#  'الكامل',
#  'المتدارك',
#  'المتقارب',
#  'المجتث',
#  'المديد',
#  'المضارع',
#  'المقتضب',
#  'المنسرح',
#  'المواليا',
#  'الهزج',
#  'الوافر',
#  'شعر التفعيلة',
#  'شعر حر',
#  'عامي',
#  'موشح'}

# %% [markdown]
# The target from this model is to know the البحر by giving the الشطر الأيسر & الشطر الأيمن

# %% [markdown]
# # Feature Engineering

# %%
class ArabicTokenizer:
    def __init__(self):
        self.movable_chars = ['َ','ٌ']
        self.tanween = "ًٌٍ"

    def transform(self, text):
        words = text.split()    
        encoded_words = []
        binary_sequences = []
        
        for word in words:
            encoded_word = ""
            binary_sequence = ""
            for char in word:
                if char in self.movable_chars:
                    encoded_word += char
                    binary_sequence += "1"
                elif char in self.tanween:
                    encoded_word += char
                    binary_sequence += "01" 
                else:
                    encoded_word += char
                    binary_sequence += "0"
            encoded_words.append(encoded_word)
            binary_sequences.append(binary_sequence)
        
        df = pd.DataFrame({'Encoded Text': encoded_words, 'Binary Sequence': binary_sequences})
        return df

# %%
tokenizer = ArabicTokenizer()

# %%
for text in data['البيت']:
    enc = tokenizer.transform(text = str(text))

# %%
text_to_transform = data['البيت']

tokenizer = ArabicTokenizer()

tokenized_text = []

for bait in text_to_transform:
    tokenized_text.append(tokenizer.transform(bait))

# %%
tokenized_text
# Out:
# [  Encoded Text Binary Sequence
#  0    خَليلَيَّ       010001001
#  1           لا              00
#  2   تَستَعجِلا      0100100100
#  3          أَن             010
#  4    تَزَوَّدا       010100100
#  5        وَأَن           01010
#  6      تَجمَعا         0100100
#  7        شَملي           01000
#  8  وَتَنتَظِرا     01010010100
#  9         غَدا            0100,
#    Encoded Text Binary Sequence
#  0         فَما            0100
#  1       لَبَثٌ         0101001
#  2       يَوماً         0100001
#  3     بِسابِقٍ       010001001
#  4      مَغنَمٍ        01001001
#  5         وَلا            0100
#  6      سُرعَتي         0100100
#  7       يَوماً         0100001
#  8   بِسابِقَةِ      0100010101
#  9       الرَدى          000100,
#     Encoded Text Binary Sequence
#  0         وَإِن           01010
#  1     تُنظِراني       010010000
#  2       اليَومَ         0001001
#  3         أَقضِ           01001
#  4      لُبانَةً       010001001
#  5  وَتَستَوجِبا    010100100100
#  6        مَنّاً         0100001
#  7       عَلَيَّ         0101001
#  8     وَتُحمَدا       010100100,
#    Encoded Text Binary Sequence
#  0    لَعَمرُكَ       010100101
#  1           ما              00
#  2        نَفسٌ          010001
#  3       بِجِدٍ         0101001
#  4     رَشيدَةٍ       010001001
#  5   تُؤامِرُني      0100010100
#  6       سِرّاً         0100001
#  7    لِأَصرِمَ       010100101
#  8      مَرثَدا         0100100,
#    Encoded Text Binary Sequence
#  0        وَإِن           01010
#  1      ظَهَرَت         0101010
#  2        مِنهُ           01001
#  3     قَوارِصُ        01000101
#  4      جَمَّةٌ        01001001
#  5    وَأَفرَعَ       010100101
#  6           في              00
#  7        لَومي           01000
#  8      مِراراً        01000001
#  9    وَأَصعَدا       010100100,
#     Encoded Text Binary Sequence
#  0          عَلى            0100
#  1         غَيرِ           01001
#  2         ذَنبٍ          010001
#  3           أَن             010
#  4        أَكونَ          010001
#  5     جَنَيتُهُ       010100101
#  6          سِوى            0100
#  7         قَولِ           01001
#  8          باغٍ           00001
#  9        كادَني          000100
#  10  فَتَجَهَّدا     01010100100,
#     Encoded Text Binary Sequence
#  0       لَعَمري         0101000
#  1       لَنِعمَ         0101001
#  2       المَرءُ         0001001
#  3         تَدعو           01000
#  4     بِحَبلِهِ       010100101
#  5          إِذا            0100
#  6            ما              00
#  7      المُنادي        00010000
#  8            في              00
#  9    المَقامَةِ      0001000101
#  10      نَدَّدا         0100100,
#     Encoded Text Binary Sequence
#  0        عَظيمُ          010001
#  1        رَمادِ          010001
#  2       القِدرِ         0001001
#  3            لا              00
#  4   مُتَعَبِّسٌ    010101001001
#  5          وَلا            0100
#  6       مُؤيِسٌ        01001001
#  7         مِنها           01000
#  8          إِذا            0100
#  9          هُوَ            0101
#  10      أَوقَدا         0100100,
#     Encoded Text Binary Sequence
#  0         وَإِن           01010
#  1      صَرَّحَت        01001010
#  2         كَحلٌ          010001
#  3      وَهَبَّت        01010010
#  4     عَرِيَّةٌ      0101001001
#  5          مِنَ            0101
#  6        الريحِ          000001
#  7           لَم             010
#  8        تَترُك          010010
#  9          لِذي            0100
#  10       المالِ          000001
#  11      مِرفَدا         0100100,
#     Encoded Text Binary Sequence
#  0       صَبَرتُ         0101001
#  1          عَلى            0100
#  2         وَطءِ           01001
#  3      المَوالي        00010000
#  4    وَحَطمِهِم      0101001010
#  5          إِذا            0100
#  6         ضَنَّ           01001
#  7            ذو              00
#  8       القُربى         0001000
#  9      عَلَيهِم        01010010
#  10    وَأَخمَدا       010100100,
#     Encoded Text Binary Sequence
#  0          وَلم            0100
#  1         يَحمِ           01001
#  2         فَرجَ           01001
#  3       الحَيِّ         0001001
#  4         إِلّا           01000
#  5      مُحافِظٌ       010001001
#  6        كَريمُ          010001
#  7     المُحَيّا       000101000
#  8        ماجِدٌ         0001001
#  9         غَيرُ           01001
#  10      أَحرَدا         0100100,
#    Encoded Text Binary Sequence
#  0         أَرى            0100
#  1       جارَتي          000100
#  2       خَفَّت          010010
#  3      وَخَفَّ         0101001
#  4     نَصيحُها        01000100
#  5      وَحُبَّ         0101001
#  6         بِها            0100
#  7        لَولا           01000
#  8       النَوى          000100
#  9   وَطُموحُها      0101000100,
#    Encoded Text Binary Sequence
#  0       فَبيني          010000
#  1          على             000
#  2        نَجمٍ          010001
#  3       شَخيسٍ         0100001
#  4     نُحوسُهُ        01000101
#  5    وَأَشأَمُ       010100101
#  6        طَيرِ           01001
#  7   الزاجِرينَ      0000010001
#  8     سَنيحُها        01000100,
#     Encoded Text Binary Sequence
#  0         فَإِن           01010
#  1       تَشغَبي         0100100
#  2    فَالشَغَبُ      0100010101
#  3         مِنّي           01000
#  4     سَجِيَّةٌ      0101001001
#  5          إِذا            0100
#  6        شيمَتي          000100
#  7           لَم             010
#  8         يُؤتَ           01001
#  9         مِنها           01000
#  10     سَجيحُها        01000100,
#    Encoded Text Binary Sequence
#  0     أُقارِضُ        01000101
#  1     أَقواماً       010000001
#  2       فَأوفي          010000
#  3    قُروضَهُم       010001010
#  4      وَعَفٌّ        01010001
#  5         إِذا            0100
#  6        أَردى           01000
#  7     النُفوسَ        00010001
#  8     شَحيحُها        01000100,
#    Encoded Text Binary Sequence
#  0         عَلى            0100
#  1        أَنَّ           01001
#  2        قَومي           01000
#  3   أَشَقَذوني      0101010000
#  4   فَأَصبَحَت      0101001010
#  5       دِياري          010000
#  6      بِأَرضٍ        01010001
#  7        غَيرِ           01001
#  8         دانٍ           00001
#  9     نُبوحُها        01000100,
#    Encoded Text Binary Sequence
#  0    تَنَفَّذَ       010100101
#  1       مِنهُم          010010
#  2     نافِذاتٌ       000100001
#  3    فَسُؤنَني       010100100
#  4    وَأَضمَرَ       010100101
#  5     أَضغاناً       010000001
#  6      عَلَيَّ         0101001
#  7     كُشوحُها        01000100,
#     Encoded Text Binary Sequence
#  0       فَقُلتُ         0101001
#  1        فِراقُ          010001
#  2        الدارِ          000001
#  3       أَجمَلُ         0100101
#  4       بَينَنا         0100100
#  5         وَقَد           01010
#  6       يَنتَئي         0100100
#  7           عَن             010
#  8          دارِ            0001
#  9         سَوءٍ          010001
#  10     نَزيحُها        01000100,
#    Encoded Text Binary Sequence
#  0         عَلى            0100
#  1      أَنَّني         0100100
#  2          قَد             010
#  3      أَدَّعي         0100100
#  4   بِأَبيهِمِ      0101000101
#  5         إِذا            0100
#  6      عَمَّتِ         0100101
#  7      الدَعوى         0001000
#  8       وَثابَ          010001
#  9     صَريحُها        01000100,
#    Encoded Text Binary Sequence
#  0      وَأَنّي         0101000
#  1         أَرى            0100
#  2         ديني            0000
#  3     يُوافِقُ        01000101
#  4      دينَهُم         0001010
#  5         إِذا            0100
#  6      نَسَكوا         0101000
#  7    أَفراعُها       010000100
#  8   وَذَبيحُها      0101000100,
#    Encoded Text Binary Sequence
#  0  وَمَنزِلَةٍ    010100101001
#  1    بِالحَجِّ       010001001
#  2        أُخرى           01000
#  3    عَرَفتُها       010100100
#  4         لَها            0100
#  5     بُقَعَةٌ       010101001
#  6           لا              00
#  7    يُستَطاعُ       010010001
#  8     بُروحُها        01000100,
#     Encoded Text Binary Sequence
#  0     بِوُدِّكِ       010100101
#  1            ما              00
#  2         قَومي           01000
#  3          عَلى            0100
#  4           أَن             010
#  5    تَرَكتِهِم      0101001010
#  6       سُلَيمى         0101000
#  7          إِذا            0100
#  8        هَبَّت          010010
#  9        شَمالٌ         0100001
#  10     وَريحُها        01000100,
#     Encoded Text Binary Sequence
#  0          إِذا            0100
#  1       النَجمُ         0001001
#  2         أَمسى           01000
#  3       مَغرِبَ         0100101
#  4       الشَمسِ         0001001
#  5       رائِباً        00010001
#  6         وَلَم           01010
#  7          يَكُ            0101
#  8         بَرقٌ          010001
#  9            في              00
#  10     السَماءِ        00010001
#  11     يُليحُها        01000100,
#     Encoded Text Binary Sequence
#  0        وَغابَ          010001
#  1        شُعاعُ          010001
#  2       الشَمسِ         0001001
#  3            في              00
#  4         غَيرِ           01001
#  5       جُلبَةٍ        01001001
#  6          وَلا            0100
#  7       غَمرَةٍ        01001001
#  8         إِلّا           01000
#  9       وَشيكاً        01000001
#  10     مُصوحُها        01000100,
#    Encoded Text Binary Sequence
#  0       وَهاجَ          010001
#  1       عَماءٌ         0100001
#  2    مُقشَعِرٌ      0100101001
#  3    كَأَنَّهُ       010100101
#  4     نَقيلَةُ        01000101
#  5        نَعلٍ          010001
#  6         بانَ            0001
#  7        مِنها           01000
#  8     سَريحُها        01000100,
#    Encoded Text Binary Sequence
#  0         إِذا            0100
#  1       عُدِمَ          010101
#  2    المَحلوبُ       000100001
#  3        عادَت           00010
#  4    عَلَيهِمُ       010100101
#  5       قُدورٌ         0100001
#  6       كَثيرٌ         0100001
#  7           في              00
#  8     القِصاعِ        00010001
#  9     قَديحُها        01000100,
#    Encoded Text Binary Sequence
#  0       يَثوبُ          010001
#  1      إِلَيها         0101000
#  2        كُلُّ           01001
#  3        ضَيفٍ          010001
#  4     وَجانِبٍ       010001001
#  5         كَما            0100
#  6        رَدَّ           01001
#  7      دَهداهَ         0100001
#  8     القِلاصِ        00010001
#  9     نَضيحُها        01000100,
#    Encoded Text Binary Sequence
#  0  بِأَيديهِمُ     01010000101
#  1    مَقرومَةٌ      0100001001
#  2   وَمَغالِقٌ     01010001001
#  3       يَعودُ          010001
#  4    بِأَرزاقِ       010100001
#  5     العِيالِ        00010001
#  6     مَنيحُها        01000100,
#    Encoded Text Binary Sequence
#  0  وَمَلمومَةٍ    010100001001
#  1           لا              00
#  2      يَخرِقُ         0100101
#  3      الطَرفُ         0001001
#  4      عَرضَها         0100100
#  5         لَها            0100
#  6      كَوكَبٌ        01001001
#  7        فَخمٌ          010001
#  8       شَديدٌ         0100001
#  9     وُضوحُها        01000100,
#    Encoded Text Binary Sequence
#  0       تَسيرُ          010001
#  1      وَتُزجي         0101000
#  2      السَمَّ         0001001
#  3        تَحتَ           01001
#  4     نُحورِها        01000100
#  5       كَريهٌ         0100001
#  6         إِلى            0100
#  7          مَن             010
#  8    فاجَأَتهُ       000101001
#  9     صَبوحُها        01000100,
#     Encoded Text Binary Sequence
#  0          عَلى            0100
#  1  مُقذَحِرّاتٍ   0100101000001
#  2       وَهُنُّ         0101001
#  3      عَوابِسٌ       010001001
#  4      ضَبائِرُ        01000101
#  5         مَوتٍ          010001
#  6            لا              00
#  7        يُراحُ          010001
#  8      مُريحُها        01000100,
#     Encoded Text Binary Sequence
#  0       نَبَذنا         0101000
#  1      إِلَيهِم        01010010
#  2       دَعوَةً        01001001
#  3          يالَ            0001
#  4        مالِكٍ         0001001
#  5          لَها            0100
#  6       إِربَةٌ        01001001
#  7           إِن             010
#  8           لَم             010
#  9         تَجِد           01010
#  10          مَن             010
#  11     يُريحُها        01000100,
#     Encoded Text Binary Sequence
#  0       فَسُرنا         0101000
#  1      عَلَيهِم        01010010
#  2       سَورَةً        01001001
#  3  ثَعلَبِيَّةً   0100101001001
#  4   وَأَسيافُنا     01010000100
#  5         يَجري           01000
#  6      عَلَيهِم        01010010
#  7      نُضوحُها        01000100,
#    Encoded Text Binary Sequence
#  0  وَأَرماحُنا     01010000100
#  1  يَنهَزنَهُم     01001001010
#  2        نَهزَ           01001
#  3      جُمَّةٍ        01001001
#  4       يَعودُ          010001
#  5     عَلَيهِم        01010010
#  6      وِردُنا         0100100
#  7   فَنَميحُها      0101000100,
#    Encoded Text Binary Sequence
#  0      فَدارَت         0100010
#  1       رَحانا          010000
#  2       ساعَةً         0001001
#  3   وَرَحاهُمُ      0101000101
#  4     وَدَرَّت        01010010
#  5      طِباقاً        01000001
#  6        بَعدَ           01001
#  7       بَكُءٍ         0101001
#  8     لُقوحُها        01000100,
#    Encoded Text Binary Sequence
#  0         فَما            0100
#  1     أَتلَفَت        01001010
#  2    أَيديهُمُ       010000101
#  3          مِن             010
#  4     نُفوسِنا        01000100
#  5        وَإِن           01010
#  6      كَرُمَت         0101010
#  7    فَإِنَّنا       010100100
#  8           لا              00
#  9     نَنوحُها        01000100,
#    Encoded Text Binary Sequence
#  0      فَقُلنا         0101000
#  1         هِيَ            0101
#  2      النُهبى         0001000
#  3      وَحَلَّ         0101001
#  4     حَرامُها        01000100
#  5      وَكانَت         0100010
#  6         حِمى            0100
#  7           ما              00
#  8      قَبلَنا         0100100
#  9   فَنُبيحُها      0101000100,
#    Encoded Text Binary Sequence
#  0      فَأُبنا         0101000
#  1       وَآبوا          010000
#  2      كُلَّنا         0100100
#  3   بِمَضيضَةٍ     01010001001
#  4  مُهَمَّلَةٍ    010100101001
#  5    أَجراحُنا       010000100
#  6   وَجُروحُها      0101000100,
#    Encoded Text Binary Sequence
#  0      وَكُنّا         0101000
#  1         إِذا            0100
#  2      أَحلامُ         0100001
#  3        قَومٍ          010001
#  4   تَغَيَّبَت      0101001010
#  5      نَشِحُّ         0101001
#  6         عَلى            0100
#  7    أَحلامِنا       010000100
#  8   فَنُريحُها      0101000100,
#     Encoded Text Binary Sequence
#  0            إن              00
#  1          أَكُ            0101
#  2           قَد             010
#  3      أَقصَرتُ        01001001
#  4           عَن             010
#  5          طولِ            0001
#  6       رِحلَةٍ        01001001
#  7          فَيا            0100
#  8         رُبَّ           01001
#  9       أَصحابٍ        01000001
#  10      بَعَثتُ         0101001
#  11       كِرامِ          010001,
#     Encoded Text Binary Sequence
#  0       فَقُلتُ         0101001
#  1         لَهُم           01010
#  2         سيروا           00000
#  3         فِدىً          010001
#  4        خالَتي          000100
#  5         لَكُم           01010
#  6          أَما            0100
#  7      تَجِدونَ        01010001
#  8        الريحَ          000001
#  9          ذاتَ            0001
#  10       سَهامِ          010001,
#    Encoded Text Binary Sequence
#  0      فَقاموا         0100000
#  1         إِلى            0100
#  2         عيسٍ           00001
#  3         قَدِ            0101
#  4     اِنضَمَّ        01001001
#  5      لَحمُها         0100100
#  6  مُوَقَّفَةٍ    010100101001
#  7    أَرساغُها       010000100
#  8      بِخَدام         0101000,
#    Encoded Text Binary Sequence
#  0      وَقُمتُ         0101001
#  1         إِلى            0100
#  2      وَجناءَ         0100001
#  3    كَالفَحلِ       010001001
#  4      جَبلَةٍ        01001001
#  5     تُجاوِبُ        01000101
#  6      شَدِّيَ         0100101
#  7      نِسعَها         0100100
#  8      بِبُغام         0101000,
#    Encoded Text Binary Sequence
#  0    فَأُدلِجُ       010100101
#  1        حَتّى           01000
#  2      تَطلُعَ         0100101
#  3      الشَمسُ         0001001
#  4      قاصِداً        00010001
#  5        وَلَو           01010
#  6      خُلِطَت         0101010
#  7    ظَلماؤُها       010000100
#  8     بِقَتامِ        01010001,
#      Encoded Text Binary Sequence
#  0  فَأَورَدتُهُم   0101001001010
#  1           ماءً           00001
#  2           عَلى            0100
#  3           حينٍ           00001
#  4        وِردِهِ         0100101
#  5         عَلَيه          010100
#  6         خَليطٌ         0100001
#  7            مِن             010
#  8          قَطاً          010001
#  9       وَحَمامِ        01010001,
#     Encoded Text Binary Sequence
#  0     وَأَهوَنُ       010100101
#  1         كَفٍّ          010001
#  2            لا              00
#  3      تَضيرُكَ        01000101
#  4       ضَيرَةً        01001001
#  5          يَدٌ           01001
#  6         بَينَ           01001
#  7         أَيدٍ          010001
#  8            في              00
#  9        إِناءِ          010001
#  10       طَعامِ          010001,
#     Encoded Text Binary Sequence
#  0          يَدٌ           01001
#  1           مِن             010
#  2        بَعيدٍ         0100001
#  3           أَو             010
#  4        قَريبٍ         0100001
#  5         أَتَت           01010
#  6          بِهِ            0101
#  7    شَآمِيَّةٌ     01001001001
#  8      غَبَراءُ        01010001
#  9          ذاتُ            0001
#  10       قَتامِ          010001,
#    Encoded Text Binary Sequence
#  0      كَأَنّي         0101000
#  1        وَقَد           01010
#  2      جاوَزتُ         0001001
#  3      تِسعينَ         0100001
#  4      حِجَّةً        01001001
#  5      خَلَعتُ         0101001
#  6         بِها            0100
#  7       يَوماً         0100001
#  8       عِذارِ          010001
#  9       لِجامي          010000,
#    Encoded Text Binary Sequence
#  0         عَلى            0100
#  1  الراحَتَينِ     00000101001
#  2      مَرَّةً        01001001
#  3       وَعَلى          010100
#  4       العَصا          000100
#  5       أَنوءُ          010001
#  6      ثَلاثاً        01000001
#  7   بَعدَهُنَّ      0100101001
#  8       قِيامي          010000,
#     Encoded Text Binary Sequence
#  0       رَمَتني         0101000
#  1        بَناتُ          010001
#  2       الدَهرِ         0001001
#  3           مِن             010
#  4         حَيثُ           01001
#  5            لا              00
#  6          أَرى            0100
#  7       فَكَيفَ         0101001
#  8         بِمَن           01010
#  9         يُرمى           01000
#  10      وَلَيسَ         0101001
#  11       بِرامِ          010001,
#       Encoded Text Binary Sequence
#  0           فَلَو           01010
#  1         أَنَّها         0100100
#  2           نَبلٌ          010001
#  3           إِذاً          010001
#  4  لَاِتَّقَيتُها  01010010100100
#  5     وَلَكِنَّني     01010100100
#  6           أُرمى           01000
#  7         بِغَيرِ         0101001
#  8          سِهامِ          010001,
#     Encoded Text Binary Sequence
#  0          إِذا            0100
#  1            ما              00
#  2         رَآني           01000
#  3        الناسُ          000001
#  4         قالوا           00000
#  5         أَلَم           01010
#  6         تَكُن           01010
#  7       حَديثاً        01000001
#  8        جَديدَ          010001
#  9       البَزِّ         0001001
#  10        غَيرَ           01001
#  11       كَهامِ          010001,
#     Encoded Text Binary Sequence
#  0       وَأَفنى         0101000
#  1          وَما            0100
#  2         أُفني           01000
#  3          مِنَ            0101
#  4       الدَهرِ         0001001
#  5       لَيلَةً        01001001
#  6         وَلَم           01010
#  7         يُغنِ           01001
#  8            ما              00
#  9      أَفنَيتُ        01001001
#  10        سِلكَ           01001
#  11       نِظامِ          010001,
#    Encoded Text Binary Sequence
#  0  وَأَهلَكَني     01010010100
#  1      تَأميلُ         0100001
#  2        يَومٍ          010001
#  3    وَلَيلَةٍ      0101001001
#  4    وَتَأميلُ       010100001
#  5         عامٍ           00001
#  6        بَعدَ           01001
#  7         ذاكَ            0001
#  8       وَعامِ          010001,
#     Encoded Text Binary Sequence
#  0            يا              00
#  1         لَهفَ           01001
#  2         نَفسي           01000
#  3          عَلى            0100
#  4      الشَبابِ        00010001
#  5         وَلَم           01010
#  6        أَفقِد          010010
#  7          بِهِ            0101
#  8           إِذ             010
#  9     فَقَدتُهُ       010100101
#  10       أَمَما          010100,
#    Encoded Text Binary Sequence
#  0          قَد             010
#  1        كُنتُ           01001
#  2           في              00
#  3      مَيعَةٍ        01001001
#  4      أُسَرُّ         0101001
#  5         بِها            0100
#  6      أَمنَعُ         0100101
#  7        ضَيمي           01000
#  8     وَأُهبِط        01010010
#  9     العُصُما        00010100,
#    Encoded Text Binary Sequence
#  0    وَأَسحَبُ       010100101
#  1      الرَيطَ         0001001
#  2   وَالبُرودَ      0100010001
#  3         إِلى            0100
#  4        أَدنى           01000
#  5       تِجاري          010000
#  6    وَأَنفُضُ       010100101
#  7     اللِمَما        00010100,
#    Encoded Text Binary Sequence
#  0           لا              00
#  1      تَغبِطِ         0100101
#  2      المَرءَ         0001001
#  3          أَن             010
#  4       يُقالَ          010001
#  5         لَهُ            0101
#  6        أَمسى           01000
#  7       فَلانٌ         0100001
#  8    لِعُمرِهِ       010100101
#  9       حَكَما          010100,
#     Encoded Text Binary Sequence
#  0           إِن             010
#  1       سَرَّهُ         0100101
#  2          طولُ            0001
#  3       عَيشِهِ         0100101
#  4       فَلَقَد         0101010
#  5         أَضحى           01000
#  6          عَلى            0100
#  7       الوَجهِ         0001001
#  8          طولُ            0001
#  9            ما              00
#  10       سَلِما          010100,
#     Encoded Text Binary Sequence
#  0         إِنَّ           01001
#  1          مِنَ            0101
#  2       القَومِ         0001001
#  3           مَن             010
#  4        يُعاشُ          010001
#  5          بِهِ            0101
#  6     وَمِنهُمُ       010100101
#  7           مَن             010
#  8          تَرى            0100
#  9          بِهِ            0101
#  10       دَسَما          010100,
#    Encoded Text Binary Sequence
#  0      تَحِنُّ         0101001
#  1      حَنيناً        01000001
#  2         إِلى            0100
#  3       مالِكٍ         0001001
#  4      فَحِنّي         0101000
#  5     حَنينَكِ        01000101
#  6        إِنّي           01000
#  7       مُعالي          010000,
#    Encoded Text Binary Sequence
#  0         إِلى            0100
#  1          دار             000
#  2        قَومٍ          010001
#  3       حِسانِ          010001
#  4     الوُجوهِ        00010001
#  5       عِظامِ          010001
#  6     القِبابِ        00010001
#  7       طِوالِ          010001
#  8      العَوال         0001000,
#        Encoded Text  Binary Sequence
#  0  فَوَجَّهتُهُنَّ  010100100101001
#  1             عَلى             0100
#  2          مَهمَهٍ         01001001
#  3           قَليلِ           010001
#  4           الوَغى           000100
#  5            غَيرَ            01001
#  6            صَوتِ            01001
#  7         الرِئالِ         00010001,
#    Encoded Text Binary Sequence
#  0      سِراعاً        01000001
#  1     دَوائِبَ        01000101
#  2           ما              00
#  3      يَنثَني         0100100
#  4           نَ              01
#  5        حَتّى           01000
#  6   اِحتَلَلنَ      0100101001
#  7      بِحَيِّ         0101001
#  8       حِلالِ          010001,
#    Encoded Text Binary Sequence
#  0      بِسَعدِ         0101001
#  1          بنِ             001
#  2    ثَعلَبَةَ       010010101
#  3    الأَكرَمي       000100100
#  4           نَ              01
#  5        أَهلِ           01001
#  6     الفِضالِ        00010001
#  7      وَأَهلِ         0101001
#  8     النَوالِ        00010001,
#    Encoded Text Binary Sequence
#  0     لَيالِيَ        01000101
#  1    يَحبونَني       010000100
#  2     وُدَّهُم        01001010
#  3    وَيَحبونَ       010100001
#  4      قِدرَكَ         0100101
#  5        غُرَّ           01001
#  6     المَحالِ        00010001,
#    Encoded Text Binary Sequence
#  0    فَتُصبِحُ       010100101
#  1           في              00
#  2      المَحلِ         0001001
#  3   مُحوَرَّةً     01001001001
#  4      لِفَيءِ         0101001
#  5   إِهالَتِها      0100010100
#  6   كَالظِلالِ      0100010001,
#    Encoded Text Binary Sequence
#  0        فَإِن           01010
#  1        كُنتِ           01001
#  2     ساقِيَةً       000101001
#  3     مَعشَراً       010010001
#  4       كِرامَ          010001
#  5   الضَرائِبِ      0001000101
#  6           في              00
#  7        كُلِّ           01001
#  8         حالِ            0001,
#    Encoded Text Binary Sequence
#  0         عَلى            0100
#  1       كَرَمٍ         0101001
#  2       وَعَلى          010100
#  3     نَجَدَةٍ       010101001
#  4      رَحيقاً        01000001
#  5       بِماءٍ         0100001
#  6       نِطافٍ         0100001
#  7       زُلالِ          010001,
#    Encoded Text Binary Sequence
#  0       فَكوني          010000
#  1    أُولَئِكَ       010010101
#  2    تَسقينَها       010000100
#  3        فِدىً          010001
#  4  لِأُولَئِكَ     01010010101
#  5         عَمي            0100
#  6       وَخالي          010000,
#    Encoded Text Binary Sequence
#  0     أَلَيسوا        01010000
#  1   الفَوارِسَ      0001000101
#  2        يَومَ           01001
#  3     الفُراتِ        00010001
#  4    وَالخَيلُ       010001001
#  5    بِالقَومِ       010001001
#  6        مِثلُ           01001
#  7     السَعالي        00010000,
#     Encoded Text Binary Sequence
#  0         وَهُم           01010
#  1           مَا             010
#  2          هُمُ            0101
#  3         عِندَ           01001
#  4         تِلكَ           01001
#  5      الهَناتِ        00010001
#  6          إِذا            0100
#  7       زَعزَعَ         0100101
#  8       الطَلحَ         0001001
#  9          ريحُ            0001
#  10     الشَمالِ        00010001,
#     Encoded Text Binary Sequence
#  0       بِدُهمٍ        01010001
#  1      ضَوامِنَ        01000101
#  2    لِلمُعتَفي      0100100100
#  3            نَ              01
#  4           أَن             010
#  5  يَمنَحوهُنَّ    010010001001
#  6         قَبلَ           01001
#  7      العِيالِ        00010001,
#    Encoded Text Binary Sequence
#  0        إِنَّ           01001
#  1        قَلبي           01000
#  2          عَن             010
#  3      تُكتَمٍ        01001001
#  4        غَيرُ           01001
#  5         سالِ            0001
#  6   تَيَّمَتني      0100101000
#  7         وَما            0100
#  8      أَرادَت         0100010
#  9       وِصالي          010000,
#       Encoded Text Binary Sequence
#  0             هَل             010
#  1            تَرى            0100
#  2          عيرَها          000100
#  3          تُجيزُ          010001
#  4         سِراعاً        01000001
#  5  كَالعَدَولِيِّ  01000101001001
#  6         رائِحاً        00010001
#  7             مِن             010
#  8          أُوالِ          010001,
#    Encoded Text Binary Sequence
#  0      نَزَلوا         0101000
#  1          مِن             010
#  2    سُوَيقَةِ       010100101
#  3       الماءِ          000001
#  4       ظُهراً         0100001
#  5        ثُمَّ           01001
#  6        راحوا           00000
#  7     لِلنَعفِ        01001001
#  8        نَعفِ           01001
#  9       مَطالِ          010001,
#    Encoded Text Binary Sequence
#  0        ثُمَّ           01001
#  1      أَضحَوا         0100100
#  2         عَلى            0100
#  3   الدَثينَةِ      0001000101
#  4           لا              00
#  5      يَألونَ         0100001
#  6          أَن             010
#  7     يَرفَعوا        01001000
#  8       صُدورَ          010001
#  9     الجِمالِ        00010001,
#    Encoded Text Binary Sequence
#  0        ثُمَّ           01001
#  1         كانَ            0001
#  2     الحِساءُ        00010001
#  3       مِنهُم          010010
#  4      مُصيفاً        01000001
#  5     ضارِباتِ        00010001
#  6     الخُدورِ        00010001
#  7        تَحتَ           01001
#  8     الهَدالِ        00010001,
#    Encoded Text Binary Sequence
#  0      فَزِعَت         0101010
#  1      تُكتَمُ         0100101
#  2      وَقالَت         0100010
#  3      عَجيباً        01000001
#  4          أَن             010
#  5      رَأَتني         0101000
#  6    تَغَيَّرَ       010100101
#  7      اليَومَ         0001001
#  8         حالي            0000,
#    Encoded Text Binary Sequence
#  0           يا              00
#  1      اِبنَةَ         0100101
#  2      الخَيرِ         0001001
#  3      إِنَّما         0100100
#  4        نَحنُ           01001
#  5        رَهنٌ          010001
#  6     لِصُروفِ        01010001
#  7    الأَيّامِ       000100001
#  8        بَعدَ           01001
#  9     اللَيالي        00010000,
#    Encoded Text Binary Sequence
#  0      جَلَّحَ         0100101
#  1      الدَهرُ         0001001
#  2    وَاِنتَحى       010100100
#  3           لي              00
#  4     وَقِدماً       010100001
#  5         كانَ            0001
#  6        يُنحي           01000
#  7       القُوى          000100
#  8         عَلى            0100
#  9      أَمثالي         0100000,
#    Encoded Text Binary Sequence
#  0   أَقصَدَتني      0100101000
#  1     سِهامُهُ        01000101
#  2          إِذ             010
#  3      رَأَتني         0101000
#  4   وَتَوَلَّت      0101010010
#  5        عَنهُ           01001
#  6      سُلَيمى         0101000
#  7       نِبالي          010000,
#    Encoded Text Binary Sequence
#  0           لا              00
#  1       عَجيبٌ         0100001
#  2         فيما            0000
#  3      رَأَيتِ         0101001
#  4      وَلَكِن         0101010
#  5       عَجَبٌ         0101001
#  6          مِن             010
#  7    تَفَرُّطِ       010100101
#  8      الآجالِ         0000001,
#    Encoded Text Binary Sequence
#  0      تُدرِكُ         0100101
#  1    التِمسَحَ       000100101
#  2  المُوَلَّعَ     00010100101
#  3           في              00
#  4        اللُج           00010
#  5         جَةِ            0101
#  6    وَالعُصمَ       010001001
#  7           في              00
#  8       رُؤوسِ          010001
#  9     الجِبالِ        00010001,
#    Encoded Text Binary Sequence
#  0   وَالفَريدَ      0100010001
#  1  المُسَفَّعَ     00010100101
#  2      الوَجهِ         0001001
#  3           ذا              00
#  4    الجُدَّةِ       000100101
#  5      يَختارُ         0100001
#  6      آمِناتِ         0010001
#  7     الرِمالِ        00010001,
#    Encoded Text Binary Sequence
#  0    وَتَصَدّى       010101000
#  1    لِتَصرَعَ       010100101
#  2     البَطَلَ        00010101
#  3        الأَر           00010
#  4         وَعَ            0101
#  5        بَينَ           01001
#  6    العَلهاءِ       000100001
#  7  وَالسِربالِ     01000100001,
#     Encoded Text Binary Sequence
#  0         أَمِن           01010
#  1        طَلَلٍ         0101001
#  2         قَفرٍ          010001
#  3         وَمِن           01010
#  4       مَنزِلٍ        01001001
#  5          عافِ            0001
#  6       عَفَتهُ         0101001
#  7        رِياحٌ         0100001
#  8           مِن             010
#  9        مَشاتٍ         0100001
#  10    وَأَصيافِ       010100001,
#    Encoded Text Binary Sequence
#  0    وَمَبرَكِ       010100101
#  1      أَذوادٍ        01000001
#  2    وَمَربَطِ       010100101
#  3       عانَةٍ         0001001
#  4         مِنَ            0101
#  5      الخَيلِ         0001001
#  6     يَحرُثنَ        01001001
#  7     الدِيارَ        00010001
#  8    بِتَطوافِ       010100001,
#    Encoded Text Binary Sequence
#  0    وَمَجمَعِ       010100101
#  1      أَحطابٍ        01000001
#  2      وَمَلقى         0101000
#  3     أَياصِرٍ       010001001
#  4         إِذا            0100
#  5   هَزهَزَتهُ      0100101001
#  6       الريحُ          000001
#  7         قامَ            0001
#  8         لَهُ            0101
#  9         نافِ            0001,
#     Encoded Text Binary Sequence
#  0       بَكَيتَ         0101001
#  1       وَأَنتَ         0101001
#  2       اليَومَ         0001001
#  3         شَيخٌ          010001
#  4     مُجَرِّبٌ      0101001001
#  5          عَلى            0100
#  6       رَأسِهِ         0100101
#  7       شَرخانِ         0100001
#  8           مِن             010
#  9         لَونِ           01001
#  10      أَصنافِ         0100001,
#     Encoded Text Binary Sequence
#  0        سَوادٌ         0100001
#  1       وَشَيبٌ        01010001
#  2         كُلُّ           01001
#  3        ذَلِكَ          010101
#  4        شامِلٌ         0001001
#  5          إِذا            0100
#  6            ما              00
#  7          صَبا            0100
#  8         شَيخٌ          010001
#  9       فَلَيسَ         0101001
#  10         لَهُ            0101
#  11         شافِ            0001,
#     Encoded Text Binary Sequence
#  0       وَحَيٍّ        01010001
#  1          مِنَ            0101
#  2     الأَحياءِ       000100001
#  3         عَودٍ          010001
#  4     عَرَمرَمٍ      0101001001
#  5       مُدِلٍّ        01010001
#  6          فَلا            0100
#  7      يَخشَونَ        01001001
#  8           مِن             010
#  9         غَيبِ           01001
#  10      أَخيافِ         0100001,
#    Encoded Text Binary Sequence
#  0      سَمَونا         0101000
#  1        لَهُم           01010
#  2          مِن             010
#  3      أَرضِنا         0100100
#  4   وَسَمائِنا      0101000100
#  5  نُغاوِرُهُم     01000101010
#  6          مِن             010
#  7        بَعدِ           01001
#  8        أَرضٍ          010001
#  9     بِإيجافِ        01000001,
#    Encoded Text Binary Sequence
#  0         عَلى            0100
#  1        كُلِّ           01001
#  2      مَعرونٍ        01000001
#  3       وَذاتِ          010001
#  4     خِزامَةٍ       010001001
#  5     مَصاعيبَ        01000001
#  6          لَم             010
#  7     يُذلَلنَ        01001001
#  8        قَبلي           01000
#  9    بِتَوقافِ       010100001,
#     Encoded Text Binary Sequence
#  0     أُولَئِكَ       010010101
#  1         قَومي           01000
#  2           آلُ             001
#  3         سَعدِ           01001
#  4           بنِ             001
#  5        مالِكٍ         0001001
#  6       فَمالوا         0100000
#  7          عَلى            0100
#  8         ضَغنٍ          010001
#  9       عَلَيَّ         0101001
#  10    وَإِلغافِ       010100001,
#    Encoded Text Binary Sequence
#  0    أَكَنَّوا       010100100
#  1      خُطوباً        01000001
#  2          قَد             010
#  3        بَدَت           01010
#  4   صَفَحاتُها      0101000100
#  5  وَأَفئِدَةً    010100101001
#  6       لَيسَت          010010
#  7      عَلَيَّ         0101001
#  8     بِأَرآفِ        01010001,
#     Encoded Text Binary Sequence
#  0       وَكُلُّ         0101001
#  1        أُناسٍ         0100001
#  2       أَقرَبُ         0100101
#  3       اليَومَ         0001001
#  4       مِنُهمُ         0101001
#  5       إِلَيَّ         0101001
#  6         وَإِن           01010
#  7         كانوا           00000
#  8        عُمانَ          010001
#  9         أُولي           01000
#  10      اِلغافِ         0100001,
#     Encoded Text Binary Sequence
#  0       وَمَولى         0101000
#  1        ضَعيفِ          010001
#  2       النَصرِ         0001001
#  3          ناءٍ           00001
#  4     مَحَلُّهُ       010100101
#  5       جَشِمتُ         0101001
#  6          لَهُ            0101
#  7            ما              00
#  8         لَيسَ           01001
#  9         مِنّي           01000
#  10      جاشِمُه         0001010,
#     Encoded Text Binary Sequence
#  0          إِذا            0100
#  1            ما              00
#  2         رَآني           01000
#  3      مُقبِلاً       010010001
#  4         شَدَّ           01001
#  5       صَوتَهُ         0100101
#  6          عَلى            0100
#  7       القِرنِ         0001001
#  8    وَاِعلَولى      0101001000
#  9          عَلى            0100
#  10          مَن             010
#  11    يُخاصِمُه       010001010,
#    Encoded Text Binary Sequence
#  0    وَأَجرَدَ       010100101
#  1      مَيّاحٍ        01000001
#  2      وَهَبتُ         0101001
#  3    بِسِرجِهِ       010100101
#  4  لِمُختَبِطٍ    010100101001
#  5         أوذي            0000
#  6       دَلالٍ         0100001
#  7    أُكارِمُه       010001010,
#    Encoded Text Binary Sequence
#  0         عَلى            0100
#  1        أَنَّ           01001
#  2        قَومي           01000
#  3    أَسلَموني       010010000
#  4    وَعُرَّتي       010100100
#  5      وَقَومُ         0101001
#  6       الفَتى          000100
#  7    أَظفارُهُ       010000101
#  8  وَدَعائِمُه     01010001010,
#    Encoded Text Binary Sequence
#  0          هَل             010
#  1      عَرَفتَ         0101001
#  2     الدِيارَ        00010001
#  3          عَن             010
#  4      أَحقابِ         0100001
#  5      دارِساً        00010001
#  6        آيُها           00100
#  7      كَخَطِّ         0101001
#  8     الكِتابِ        00010001,
#    Encoded Text Binary Sequence
#  0    وَكَأَنّي       010101000
#  1        لَمّا           01000
#  2      عَرَفتُ         0101001
#  3       دِيارَ          010001
#  4           ال              00
#  5        حَيِّ           01001
#  6    بِالسَفحِ       010001001
#  7          عَن             010
#  8       يَمينِ          010001
#  9     الحُبابِ        00010001,
#    Encoded Text Binary Sequence
#  0       يَسَرٌ         0101001
#  1       حارَضَ          000101
#  2   الرِبابَةَ      0001000101
#  3        حَتّى           01000
#  4         راحَ            0001
#  5       قَصراً         0100001
#  6       وَضيمَ          010001
#  7           في              00
#  8    الأَندابِ       000100001,
#     Encoded Text Binary Sequence
#  0       جَزَعاً        01010001
#  1         مِنكَ           01001
#  2       يَاِبنَ         0101001
#  3         سَعدٍ          010001
#  4         وَقَد           01010
#  5           أَخ             010
#  6          لَقَ            0101
#  7         مِنكَ           01001
#  8      المَشيبُ        00010001
#  9         ثَوبَ           01001
#  10     الشَبابِ        00010001,
#    Encoded Text Binary Sequence
#  0          هَل             010
#  1           لا              00
#  2    يُهَيِّجُ       010100101
#  3      شَوقُكَ         0100101
#  4     الطَلَلُ        00010101
#  5          أَم             010
#  6           لا              00
#  7    يُفَرِّطُ       010100101
#  8      شَيخَكَ         0100101
#  9     الغَزَلُ        00010101,
#    Encoded Text Binary Sequence
#  0          أَم             010
#  1           ذا              00
#  2     القَطينَ        00010001
#  3       أَصابَ          010001
#  4    مَقتَلَهُ       010010101
#  5        مِنهُ           01001
#  6     وَخانوهُ        01000001
#  7         إِذا            0100
#  8   اِحتَمَلوا      0100101000,
#    Encoded Text Binary Sequence
#  0    وَرَأَيتَ       010101001
#  1    ظُعنَهُمُ       010010101
#  2  مُقَفِّيَةً    010100101001
#  3        تَعلو           01000
#  4   المَخارِمَ      0001000101
#  5      سَيرُها         0100100
#  6       رَمَلُ          010101,
#      Encoded Text Binary Sequence
#  0         قَنَأَ          010101
#  1       العُهونَ        00010001
#  2           عَلى            0100
#  3     حَوامِلِها      0100010100
#  4         وَعَلى          010100
#  5  الرُهاوِيّاتِ   0001000100001
#  6     وَالكِلَلُ      0100010101,
#    Encoded Text Binary Sequence
#  0    وَكَأَنَّ       010101001
#  1      غِزلانَ         0100001
#  2     الصَريمِ        00010001
#  3         بِها            0100
#  4        تَحتَ           01001
#  5     الخُدورِ        00010001
#  6    يُظِلُّها       010100100
#  7     الظُلَلُ        00010101,
#    Encoded Text Binary Sequence
#  0        تامَت           00010
#  1     فُؤادَكَ        01000101
#  2        يَومَ           01001
#  3    بَينِهِمُ       010010101
#  4        عِندَ           01001
#  5  التَفَرُّقِ     00010100101
#  6      ظَبيَةٌ        01001001
#  7       عُطُلُ          010101,
#    Encoded Text Binary Sequence
#  0      شَنِفَت         0101010
#  1         إِلى            0100
#  2       رَشَأٍ         0101001
#  3   تُرَبِّبُه      0101001010
#  4       وَلَها          010100
#  5       بِذاتِ          010001
#  6       الحاذِ          000001
#  7    مُعتَزَلُ       010010101,
#     Encoded Text Binary Sequence
#  0          ظِلٌ           01001
#  1          إِذا            0100
#  2       ضَحِيَت         0101010
#  3  وَمُرَتَقَبُ    010101010101
#  4          وَلا            0100
#  5        يَكونُ          010001
#  6     لِلَيلِها       010100100
#  7        دَغَلُ          010101,
#    Encoded Text Binary Sequence
#  0       فَسَقى          010100
#  1   مَنازِلَها      0100010100
#  2  وَحِلَّتَها     01010010100
#  3        قِردُ           01001
#  4     الرَبابِ        00010001
#  5    لِصَوتِهِ       010100101
#  6       زَجَلُ          010101,
#    Encoded Text Binary Sequence
#  0        أَبدى           01000
#  1   مَحاسِنَهُ      0100010101
#  2   لِناظِرِهِ      0100010101
#  3         ذاتَ            0001
#  4     العِشاءِ        00010001
#  5    مُهَلَّبٌ      0101001001
#  6       خَضِلُ          010101,
#    Encoded Text Binary Sequence
#  0  مُتَحَلِّبٌ    010101001001
#  1        تَهوي           01000
#  2     الجَنوبُ        00010001
#  3         بِهِ            0101
#  4     فَتَكادُ        01010001
#  5    تَعدِلُهُ       010010101
#  6  وَيَنجَفِلُ     01010010101,
#    Encoded Text Binary Sequence
#  0      وَضَعَت         0101010
#  1         لَدى            0100
#  2    الأَصناعِ       000100001
#  3     ضاحِيَةً       000101001
#  4       فَوَهى          010100
#  5     السُيوبُ        00010001
#  6    وَحُطَّتِ       010100101
#  7     العِجَلُ        00010101,
#    Encoded Text Binary Sequence
#  0       فَسَقى          010100
#  1      اِمرِأَ         0100101
#  2      القَيسِ         0001001
#  3          بنِ             001
#  4     عَمَرَةَ        01010101
#  5        إِنَّ           01001
#  6  الأَكرَمينَ     00010010001
#  7   لِذِكرِهِم      0101001010
#  8       نَبَلُ          010101,
#    Encoded Text Binary Sequence
#  0          كَم             010
#  1      طَعنَةٍ        01001001
#  2         لَكَ            0101
#  3        غَيرِ           01001
#  4     طائِشَةٍ       000101001
#  5           ما              00
#  6          إِن             010
#  7       يَكونُ          010001
#  8    لِجُرحِها       010100100
#  9       خَلَلُ          010101,
#    Encoded Text Binary Sequence
#  0  فَطَعَنتَها     01010100100
#  1    وَضَرَبتَ       010101001
#  2     ثانِيَةً       000101001
#  3        أُخرى           01000
#  4    وَتَنزِلُ       010100101
#  5          إِن             010
#  6         هُمُ            0101
#  7      نَزَلوا         0101000,
#    Encoded Text Binary Sequence
#  0       يَهَبُ          010101
#  1     المَخاضَ        00010001
#  2         عَلى            0100
#  3   غَوارِبِها      0100010100
#  4       زَبَدُ          010101
#  5     الفُحولِ        00010001
#  6     مَعانُها        01000100
#  7       بَقِلُ          010101,
#    Encoded Text Binary Sequence
#  0   وَعِشارُها      0101000100
#  1        بَعدَ           01001
#  2     المَخاضِ        00010001
#  3        وَقَد           01010
#  4        صافَت           00010
#  5      وَعَمَّ         0101001
#  6     رِباعَها        01000100
#  7     النَفَلُ        00010101,
#     Encoded Text Binary Sequence
#  0        وَإِذا          010100
#  1  المُجَزِّىءُ    000101001001
#  2          حانَ            0001
#  3     مَشرَبُهُ       010010101
#  4         عِندَ           01001
#  5      المَصيفِ        00010001
#  6     وَسَرَّهُ       010100101
#  7      النَهَلُ        00010101,
#    Encoded Text Binary Sequence
#  0        رَشفُ           01001
#  1     الذِنابِ        00010001
#  2         عَلى            0100
#  3   جَماجِمِها      0100010100
#  4           ما              00
#  5          إِن             010
#  6       يَكونُ          010001
#  7    لِحَوضِها       010100100
#  8       سَمَلُ          010101,
#    Encoded Text Binary Sequence
#  0      نَأَتكَ         0101001
#  1     أُمامَةُ        01000101
#  2        إِلّا           01000
#  3      سُؤالاً        01000001
#  4      وَإِلّا         0101000
#  5      خَيالاً        01000001
#  6       يُوافي          010000
#  7       خَيالا          010000,
#    Encoded Text Binary Sequence
#  0       يُوافي          010000
#  1          مَع             010
#  2      اللَيلِ         0001001
#  3     ميعادُها        00000100
#  4      وَيَأبى         0101000
#  5         مَعَ            0101
#  6      الصُبحِ         0001001
#  7        إِلّا           01000
#  8       زِيالا          010000,
#    Encoded Text Binary Sequence
#  0     فَذَلِكَ        01010101
#  1      تَبذُلُ         0100101
#  2          مِن             010
#  3      وُدِّها         0100100
#  4        وَلَو           01010
#  5      شَهِدَت         0101010
#  6          لَم             010
#  7       تُواتِ          010001
#  8     النَوالا        00010000,
#    Encoded Text Binary Sequence
#  0        وَقَد           01010
#  1         ريعَ            0001
#  2        قَلبي           01000
#  3          إِذ             010
#  4     أَعلَنوا        01001000
#  5       وَقيلَ          010001
#  6      أَجَدَّ         0101001
#  7     الخَليطُ        00010001
#  8    اِحتِمالا       010010000,
#    Encoded Text Binary Sequence
#  0      وَحَثَّ         0101001
#  1         بِها            0100
#  2   الحادِيانِ      0000010001
#  3     النَجاءَ        00010001
#  4         مَعَ            0101
#  5      الصُبحِ         0001001
#  6        لَمّا           01000
#  7   اِستَشاروا      0100100000
#  8     الجِمالا        00010000,
#    Encoded Text Binary Sequence
#  0     بَوازِلَ        01000101
#  1        تُحدى           01000
#  2  بِأَحداجِها     01010000100
#  3   وَيُحذَينَ      0101001001
#  4        بَعدَ           01001
#  5       نِعالٍ         0100001
#  6       نِعالا          010000,
#    Encoded Text Binary Sequence
#  0      فَلَمّا         0101000
#  1       نَأَوا          010100
#  2      سَبَقَت         0101010
#  3      عَبرَتي         0100100
#  4     وَأَذرَت        01010010
#  5         لَها            0100
#  6        بَعدَ           01001
#  7        سَجلٍ          010001
#  8       سِجالا          010000,
#    Encoded Text Binary Sequence
#  0       تَراها          010000
#  1         إِذا            0100
#  2   اِحتَثَّها      0100100100
#  3     الحادِيا        00000100
#  4           نِ              01
#  5    بِالخَبتِ       010001001
#  6     يُرقِلنَ        01001001
#  7       سَيراً         0100001
#  8       عِجالا          010000,
#    Encoded Text Binary Sequence
#  0  فَبِالظِلِّ     01010001001
#  1     بُدِّلنَ        01001001
#  2        بَعدَ           01001
#  3     الهَجيرِ        00010001
#  4      وَبَعدَ         0101001
#  5     الحِجالِ        00010001
#  6      أَلِفنَ         0101001
#  7     الرِحالا        00010000,
#    Encoded Text Binary Sequence
#  0    وَفيهِنَّ       010001001
#  1      خَولَةُ         0100101
#  2        زَينُ           01001
#  3       النِسا          000100
#  4           ءِ              01
#  5        زادَت           00010
#  6         عَلى            0100
#  7       الناسِ          000001
#  8       طُرّاً         0100001
#  9       جَمالا          010000,
#    Encoded Text Binary Sequence
#  0         لَها            0100
#  1        عَينُ           01001
#  2      حَوراءَ         0100001
#  3           في              00
#  4      رَوضَةٍ        01001001
#  5      وَتَقرو         0101000
#  6         مَعَ            0101
#  7      النَبتِ         0001001
#  8       أَرطىً         0100001
#  9       طِوالا          010000,
#    Encoded Text Binary Sequence
#  0      وَتُجري         0101000
#  1     السِواكَ        00010001
#  2         عَلى            0100
#  3       بارِدٍ         0001001
#  4       يُخالُ          010001
#  5     السَيالَ        00010001
#  6      وَلَيسَ         0101001
#  7     السَيالا        00010000,
#    Encoded Text Binary Sequence
#  0      كَأَنَّ         0101001
#  1     المُدامَ        00010001
#  2      بُعَيدَ         0101001
#  3     المَنامِ        00010001
#  4      عَلَيها         0101000
#  5    وَتَسقيكَ       010100001
#  6       عَذباً         0100001
#  7       زُلالا          010000,
#    Encoded Text Binary Sequence
#  0      كَأَنَّ         0101001
#  1   الذَوائِبَ      0001000101
#  2           في              00
#  3      فَرعِها         0100100
#  4       حِبالٌ         0100001
#  5    تُوَصِّلُ       010100101
#  6         فيها            0000
#  7       حِبالا          010000,
#    Encoded Text Binary Sequence
#  0      وَوَجهٌ        01010001
#  1       يَحارُ          010001
#  2         لَهُ            0101
#  3   الناظِرونَ      0000010001
#  4  يَخالونَهُم     01000001010
#  5          قَد             010
#  6     أَهَلّوا        01010000
#  7       هِلالا          010000,
#    Encoded Text Binary Sequence
#  0         إِلى            0100
#  1       كَفَلٍ         0101001
#  2        مِثلِ           01001
#  3        دِعصِ           01001
#  4       النَقا          000100
#  5      وَكَفٍّ        01010001
#  6    تُقَلِّبُ       010100101
#  7        بيضاً          000001
#  8       طِفالا          010000,
#    Encoded Text Binary Sequence
#  0      فَبانَت         0100010
#  1         وَما            0100
#  2        نِلتُ           01001
#  3          مِن             010
#  4      وُدِّها         0100100
#  5      قِبالاً        01000001
#  6         وَلا            0100
#  7           ما              00
#  8       يُساوي          010000
#  9       قِبالا          010000,
#    Encoded Text Binary Sequence
#  0      وَكَيفَ         0101001
#  1    تَبُتّينَ       010100001
#  2        حَبلَ           01001
#  3       الصَفا          000100
#  4           ءِ              01
#  5          مِن             010
#  6       ماجِدٍ         0001001
#  7           لا              00
#  8       يُريدُ          010001
#  9    اِعتِزالا       010010000,
#     Encoded Text Binary Sequence
#  0        أَرادَ          010001
# ...
#  4         شَقِّ           01001
#  5       رَأسِهِ         0100101
#  6          مِنَ            0101
#  7       السُقمِ         0001001
#  8            ما              00
#  9      غَيَّرتُ        01001001
#  10          مِن             010
#  11        خَطِّ           01001
#  12       كاتِبِ          000101,
#     Encoded Text Binary Sequence
#  0   تُخَوِّفُني     01010010100
#  1          دونَ            0001
#  2        الَّذي          000100
#  3       أَمَرَت         0101010
#  4          بِهِ            0101
#  5         وَلَم           01010
#  6         تَدرِ           01001
#  7         أَنَّ           01001
#  8        العارَ          000001
#  9         شَرُّ           01001
#  10   العَواقِبِ      0001000101,
#    Encoded Text Binary Sequence
#  0         وَلا            0100
#  1        بُدَّ           01001
#  2          مِن             010
#  3        يَومٍ          010001
#  4      أَغَرَّ         0101001
#  5    مُحَجَّلٍ      0101001001
#  6       يَطولُ          010001
#  7    اِستِماعي       010010000
#  8      بَعدَهُ         0100101
#  9  لِلنَوادِبِ     01001000101,
#     Encoded Text Binary Sequence
#  0        يَهونُ          010001
#  1          عَلى            0100
#  2         مِثلي           01000
#  3          إِذا            0100
#  4          رامَ            0001
#  5        حاجَةً         0001001
#  6        وُقوعُ          010001
#  7      العَوالي        00010000
#  8        دونَها          000100
#  9  وَالقَواضِبِ    010001000101,
#    Encoded Text Binary Sequence
#  0       كَثيرُ          010001
#  1       حَياةِ          010001
#  2      المَرءِ         0001001
#  3        مِثلُ           01001
#  4     قَليلِها        01000100
#  5       يَزولُ          010001
#  6       وَباقي          010000
#  7      عَيشِهِ         0100101
#  8        مِثلُ           01001
#  9       ذاهِبِ          000101,
#     Encoded Text Binary Sequence
#  0       إِلَيكِ         0101001
#  1       فَإِنّي         0101000
#  2         لَستُ           01001
#  3        مِمَّن          010010
#  4          إِذا            0100
#  5       اِتَّقى         0100100
#  6        عِضاضَ          010001
#  7      الأَفاعي        00010000
#  8          نامَ            0001
#  9         فَوقَ           01001
#  10   العَقارِبِ      0001000101,
#    Encoded Text Binary Sequence
#  0       أَتاني          010000
#  1       وَعيدُ          010001
#  2  الأَدعِياءِ     00010010001
#  3   وَأَنَّهُم      0101001010
#  4     أَعَدّوا        01010000
#  5         لِيَ            0101
#  6     السودانَ        00000001
#  7           في              00
#  8        كَفرِ           01001
#  9       عاقِبِ          000101,
#      Encoded Text Binary Sequence
#  0          وَلَو           01010
#  1        صَدَقوا         0101000
#  2             في              00
#  3       جَدِّهِم        01001010
#  4   لَحَذِرتُهُم    010101001010
#  5          فَهَل           01010
#  6           فيَّ            0001
#  7          وَحدي           01000
#  8       قَولُهُم        01001010
#  9          غَيرُ           01001
#  10        كاذِبِ          000101,
#    Encoded Text Binary Sequence
#  0      إِلَيَّ         0101001
#  1      لَعَمري         0101000
#  2        قَصدُ           01001
#  3        كُلِّ           01001
#  4     عَجيبَةٍ       010001001
#  5      كَأَنّي         0101000
#  6       عَجيبٌ         0100001
#  7           في              00
#  8       عُيونِ          010001
#  9   العَجائِبِ      0001000101,
#    Encoded Text Binary Sequence
#  0      بِأَيِّ         0101001
#  1       بِلادٍ         0100001
#  2          لَم             010
#  3      أَجُرَّ         0101001
#  4     ذُؤابَتي        01000100
#  5      وَأَيُّ         0101001
#  6       مَكانٍ         0100001
#  7          لَم             010
#  8      تَطَأهُ         0101001
#  9     رَكائِبي        01000100,
#     Encoded Text Binary Sequence
#  0       كَأَنَّ         0101001
#  1        رَحيلي          010000
#  2          كانَ            0001
#  3           مِن             010
#  4         كَفِّ           01001
#  5        طاهِرٍ         0001001
#  6     فَأَثبَتَ       010100101
#  7          كوري            0000
#  8            في              00
#  9        ظُهورِ          010001
#  10   المَواهِبِ      0001000101,
#     Encoded Text Binary Sequence
#  0         فَلَم           01010
#  1         يَبقَ           01001
#  2         خَلقٌ          010001
#  3           لَم             010
#  4       يَرِدنَ         0101001
#  5      فِنائَهُ        01000101
#  6       وَهُنَّ         0101001
#  7          لَهُ            0101
#  8         شِربٌ          010001
#  9        وُرودَ          010001
#  10   المَشارِبِ      0001000101,
#    Encoded Text Binary Sequence
#  0        فَتىً          010001
#  1   عَلَّمَتهُ      0100101001
#  2      نَفسُهُ         0100101
#  3   وَجُدودُهُ      0101000101
#  4       قِراعَ          010001
#  5     الأَعادي        00010000
#  6  وَاِبتِذالَ     01010010001
#  7   الرَغائِبِ      0001000101,
#     Encoded Text Binary Sequence
#  0         فَقَد           01010
#  1       غَيَّبَ         0100101
#  2     الشُهّادَ       000100001
#  3           عَن             010
#  4         كُلِّ           01001
#  5       مَوطِنٍ        01001001
#  6       وَرَدَّ         0101001
#  7          إِلى            0100
#  8     أَوطانِهِ       010000101
#  9         كُلَّ           01001
#  10       غائِبِ          000101,
#      Encoded Text Binary Sequence
#  0           كَذا            0100
#  1  الفاطِمِيّونَ   0000010100001
#  2         النَدى          000100
#  3             في              00
#  4      بَنانِهِم       010001010
#  5        أَعَزُّ         0101001
#  6      اِمِّحاءً      0100100001
#  7            مِن             010
#  8         خُطوطِ          010001
#  9     الرَواجِبِ      0001000101,
#    Encoded Text Binary Sequence
#  0       أُناسٌ         0100001
#  1         إِذا            0100
#  2       لاقَوا          000100
#  3        عِدىً          010001
#  4  فَكَأَنَّما     01010100100
#  5       سِلاحُ          010001
#  6       الَّذي          000100
#  7       لاقَوا          000100
#  8       غُبارُ          010001
#  9   السَلاهِبِ      0001000101,
#    Encoded Text Binary Sequence
#  0       رَمَوا          010100
#  1   بِنَواصيها      0101000000
#  2    القِسِيَّ       000101001
#  3    فَجِئنَها       010100100
#  4       دَوامي          010000
#  5     الهَوادي        00010000
#  6     سالِماتِ        00010001
#  7   الجَوانِبِ      0001000101,
#    Encoded Text Binary Sequence
#  0     أولَئِكَ        00010101
#  1        أَحلى           01000
#  2          مِن             010
#  3       حَياةٍ         0100001
#  4     مُعادَةٍ       010001001
#  5    وَأَكثَرُ       010100101
#  6       ذِكراً         0100001
#  7          مِن             010
#  8       دُهورِ          010001
#  9   الشَبائِبِ      0001000101,
#     Encoded Text Binary Sequence
#  0       نَصَرتَ         0101001
#  1      عَلِيّاً       010100001
#  2            يا              00
#  3       اِبنَهُ         0100101
#  4    بِبَواتِرٍ     01010001001
#  5          مِنَ            0101
#  6       الفِعلِ         0001001
#  7            لا              00
#  8         فَلٌّ          010001
#  9          لَها            0100
#  10           في              00
#  11   المَضارِبِ      0001000101,
#    Encoded Text Binary Sequence
#  0    وَأَبهَرُ       010100101
#  1        آياتِ           00001
#  2  التِهامِيِّ     00010001001
#  3      أَنَّهُ         0100101
#  4       أَبوكَ          010001
#  5      وَأَجدى         0101000
#  6      مالَكُم         0001010
#  7          مِن             010
#  8     مَناقِبِ        01000101,
#     Encoded Text Binary Sequence
#  0          إِذا            0100
#  1           لَم             010
#  2         تَكُن           01010
#  3         نَفسُ           01001
#  4      النَسيبِ        00010001
#  5     كَأَصلِهِ       010100101
#  6        فَماذا          010000
#  7        الَّذي          000100
#  8         تُغني           01000
#  9        كِرامُ          010001
#  10   المَناصِبِ      0001000101,
#    Encoded Text Binary Sequence
#  0         وَما            0100
#  1      قَرُبَت         0101010
#  2      أَشباهُ         0100001
#  3        قَومٍ          010001
#  4     أَباعِدٍ       010001001
#  5         وَلا            0100
#  6      بَعُدَت         0101010
#  7      أَشباهُ         0100001
#  8        قَومٍ          010001
#  9     أَقارِبِ        01000101,
#     Encoded Text Binary Sequence
#  0          إِذا            0100
#  1     عَلَوِيٌّ      0101010001
#  2           لَم             010
#  3         يَكُن           01010
#  4         مِثلَ           01001
#  5        طاهِرٍ         0001001
#  6          فَما            0100
#  7          هُوَ            0101
#  8         إِلّا           01000
#  9       حُجَّةٌ        01001001
#  10  لِلنَواصِبِ     01001000101,
#    Encoded Text Binary Sequence
#  0     يَقولونَ        01000001
#  1      تَأثيرُ         0100001
#  2   الكَواكِبِ      0001000101
#  3           في              00
#  4       الوَرى          000100
#  5         فَما            0100
#  6       بالُهُ          000101
#  7    تَأثيرُهُ       010000101
#  8           في              00
#  9   الكَواكِبِ      0001000101,
#     Encoded Text Binary Sequence
#  0          عَلا            0100
#  1        كَتَدَ          010101
#  2       الدُنيا         0001000
#  3          إِلى            0100
#  4         كُلِّ           01001
#  5        غايَةٍ         0001001
#  6        تَسيرُ          010001
#  7          بِهِ            0101
#  8         سَيرَ           01001
#  9      الذَلولِ        00010001
#  10     بِراكِبِ        01000101,
#     Encoded Text Binary Sequence
#  0       وَحُقَّ         0101001
#  1          لَهُ            0101
#  2           أَن             010
#  3       يَسبِقَ         0100101
#  4        الناسَ          000001
#  5       جالِساً        00010001
#  6     وَيُدرِكَ       010100101
#  7         مالَم           00010
#  8      يُدرِكوا        01001000
#  9         غَيرَ           01001
#  10       طالِبِ          000101,
#    Encoded Text Binary Sequence
#  0      وَيُحذى         0101000
#  1     عَرانينَ        01000001
#  2     المُلوكِ        00010001
#  3    وَإِنَّها       010100100
#  4        لِمَن           01010
#  5    قَدَمَيهِ       010101001
#  6           في              00
#  7      أَجَلِّ         0101001
#  8   المَراتِبِ      0001000101,
#    Encoded Text Binary Sequence
#  0         يَدٌ           01001
#  1    لِلزَمانِ       010010001
#  2      الجَمعُ         0001001
#  3        بَيني           01000
#  4    وَبَينَهُ       010100101
#  5  لِتَفريقِهِ     01010000101
#  6        بَيني           01000
#  7      وَبَينَ         0101001
#  8   النَوائِبِ      0001000101,
#    Encoded Text Binary Sequence
#  0         هُوَ            0101
#  1        اِبنُ           01001
#  2       رَسولِ          010001
#  3       اللَهِ          000101
#  4      وَاِبنُ         0101001
#  5    وَصِيِّهِ       010100101
#  6  وَشِبهُهُما     01010010100
#  7     شَبَّهتُ        01001001
#  8        بَعدَ           01001
#  9   التَجارِبِ      0001000101,
#     Encoded Text Binary Sequence
#  0          يَرى            0100
#  1         أَنَّ           01001
#  2            ما              00
#  3            ما              00
#  4          بانَ            0001
#  5         مِنكَ           01001
#  6      لِضارِبٍ       010001001
#  7     بِأَقتَلَ       010100101
#  8         مِمّا           01000
#  9          بانَ            0001
#  10        مِنكَ           01001
#  11     لِعائِبِ        01000101,
#     Encoded Text Binary Sequence
#  0          أَلا            0100
#  1       أَيُّها         0100100
#  2        المالُ          000001
#  3        الَّذي          000100
#  4           قَد             010
#  5      أَبادَهُ        01000101
#  6       تَعَزَّ         0101001
#  7        فَهَذا          010100
#  8       فِعلُهُ         0100101
#  9            في              00
#  10   الكَتائِبِ      0001000101,
#     Encoded Text Binary Sequence
#  0     لَعَلَّكَ       010100101
#  1            في              00
#  2         وَقتٍ          010001
#  3       شَغَلتَ         0101001
#  4      فُؤادَهُ        01000101
#  5          عَنِ            0101
#  6        الجودِ          000001
#  7           أَو             010
#  8      كَثَّرتَ        01001001
#  9         جَيشَ           01001
#  10     مُحارِبِ        01000101,
#    Encoded Text Binary Sequence
#  0      حَمَلتُ         0101001
#  1      إِلَيهِ         0101001
#  2          مِن             010
#  3       لِساني          010000
#  4     حَديقَةً       010001001
#  5       سَقاها          010000
#  6       الحِجى          000100
#  7        سَقيَ           01001
#  8     الرِياضَ        00010001
#  9   السَحائِبِ      0001000101,
#     Encoded Text Binary Sequence
#  0    فَحُيِّيتَ      0101001001
#  1         خَيرَ           01001
#  2         اِبنٍ          010001
#  3       لِخَيرِ         0101001
#  4          أَبٍ           01001
#  5          بِها            0100
#  6     لِأَشرَفِ       010100101
#  7         بَيتٍ          010001
#  8            في              00
#  9       لُؤَيِّ         0101001
#  10          بنِ             001
#  11       غالِبِ          000101,
#     Encoded Text Binary Sequence
#  0          مَنِ            0101
#  1     الجَآذِرُ       000100101
#  2            في              00
#  3         زِيِّ           01001
#  4    الأَعاريبِ      0001000001
#  5         حُمرَ           01001
#  6        الحُلى          000100
#  7    وَالمَطايا      0100010000
#  8  وَالجَلابيبِ    010001000001,
#    Encoded Text Binary Sequence
#  0          إِن             010
#  1        كُنتَ           01001
#  2      تَسأَلُ         0100101
#  3       شَكّاً         0100001
#  4           في              00
#  5   مَعارِفِها      0100010100
#  6        فَمَن           01010
#  7       بَلاكَ          010001
#  8    بِتَسهيدٍ      0101000001
#  9    وَتَعذيبِ       010100001,
#    Encoded Text Binary Sequence
#  0           لا              00
#  1      تَجزِني         0100100
#  2      بِضَناً        01010001
#  3           بي              00
#  4      بَعدَها         0100100
#  5       بَقَرٌ         0101001
#  6        تَجزي           01000
#  7     دُموعِيَ        01000101
#  8     مَسكوباً       010000001
#  9    بِمَسكوبِ       010100001,
#    Encoded Text Binary Sequence
#  0     سَوائِرٌ       010001001
#  1      رُبَّما         0100100
#  2        سارَت           00010
#  3   هَوادِجُها      0100010100
#  4     مَنيعَةً       010001001
#  5        بَينَ           01001
#  6      مَطعونٍ        01000001
#  7    وَمَضروبِ       010100001,
#    Encoded Text Binary Sequence
#  0    وَرُبَّما       010100100
#  1      وَخَدَت         0101010
#  2        أَيدي           01000
#  3     المَطيِّ        00010001
#  4         بِها            0100
#  5         عَلى            0100
#  6       نَجيعٍ         0100001
#  7         مِنَ            0101
#  8    الفُرسانِ       000100001
#  9      مَصبوبِ         0100001,
#     Encoded Text Binary Sequence
#  0           كَم             010
#  1       زَورَةٍ        01001001
#  2          لَكَ            0101
#  3            في              00
#  4     الأَعرابِ       000100001
#  5      خافِيَةٍ       000101001
#  6         أَدهى           01000
#  7         وَقَد           01010
#  8       رَقَدوا         0101000
#  9           مِن             010
#  10      زَورَةِ         0100101
#  11       الذيبِ          000001,
#    Encoded Text Binary Sequence
#  0    أَزورُهُم       010001010
#  1     وَسَوادُ        01010001
#  2      اللَيلِ         0001001
#  3      يَشفَعُ         0100101
#  4           لي              00
#  5    وَأَنثَني       010100100
#  6     وَبَياضُ        01010001
#  7      الصُبحِ         0001001
#  8        يُغري           01000
#  9           بي              00,
#    Encoded Text Binary Sequence
#  0          قَد             010
#  1      وافَقوا         0001000
#  2      الوَحشَ         0001001
#  3           في              00
#  4        سُكنى           01000
#  5   مَراتِعِها      0100010100
#  6   وَخالَفوها      0100010000
#  7    بِتَقويضٍ      0101000001
#  8    وَتَطنيبِ       010100001,
#    Encoded Text Binary Sequence
#  0    جِيرانُها       010000100
#  1       وَهُمُ          010101
#  2        شَرُّ           01001
#  3     الجِوارِ        00010001
#  4         لَها            0100
#  5    وَصَحبُها       010100100
#  6       وَهُمُ          010101
#  7        شَرُّ           01001
#  8   الأَصاحيبِ      0001000001,
#    Encoded Text Binary Sequence
#  0       فُؤادُ          010001
#  1        كُلِّ           01001
#  2      مُحِبٍّ        01010001
#  3           في              00
#  4   بُيوتِهِمِ      0100010101
#  5       وَمالُ          010001
#  6        كُلِّ           01001
#  7       أَخيذِ          010001
#  8       المالِ          000001
#  9      مَحروبِ         0100001,
#  ...]

# %%
len(tokenized_text)
# Out:
# 1831770

# %%
import re
import nltk
